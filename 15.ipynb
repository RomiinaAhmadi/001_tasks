# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("heart.csv")
df[['age', 'oldpeak', 'thalach', 'chol', 'trestbps']].hist(bins=30,
                                                           figsize=(10, 5))
plt.show()

# %% [markdown]
# Analysis of Question 15
#
# هیستوگرام نموداری است که توزیع داده های عددی را نشان میدهد
# با بازه بندی تعداد زیادی از داده هارا دسته بندی میکند و به جای نشان دادن تعداد زیادی از داده ها از این دسته بندی ها استفاده میکند
# و برای داده های پیوسته استفاده میوشود.
# از هیستوگرام میفهمیم که بیشتر داده ها در چه محدوده ای قرار دارند
# و داده های پرت و میزان چولگی(در صورت وجود)وتقارن توزیع و قله بودن یا نبودن نمودار
# قصد ما نشان دادن نمودار هیستوگرام برای تمام ویژگی های عددی دیتاست است ولی باید توجه داشته باشیم که ستون هایی وجود دارند که هر چند از عدد برای رکورد ها استفاده شده
# ولی این اعداد boolهستند و به معنی بودن یا نبودن هستند
# از اپشن های هیستوگرام میتوان به تعیین کردن بازه هر گروه اشاره کرد binیعنی هر دسته چندتایی باشد
# با نگاه کردن به نمودار های هر ستون میزان داده های پرت ان ها را درمیابیم
#
#
# در بعضی از نمودار ها چولگی داریم مثل chol ,oldpeakوtrestbps
