# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("heart.csv")
# print(df['chol'].describe())
df.groupby('target')['chol'].mean()
sns.boxplot(x="target", y="chol", data=df)

plt.show()

# %% [markdown]
# Analysis of Question 23
#
# هدف ما در این دیتاست ستون تارگت است
# پس برای اینکه با توجه به بالا پایین شدن کلسترل میزان مریضی بیشتر یا کمتر را محاسبه کنیم باید کلسترل را با توجه به ستون تارگت مقایسه کنیم
# تارگت ما به دو دسته ی بیمار هستند و بیمار نیستند دسته بندی میشوند
# میانگین کلسترل بر اساس بیمار هستند و بیمار نیستند را حساب میکنیم که جواب سوال را بیابیم:سوال:ایا بیماران کلسترل بیشتری دارند یا نه
# چرا boxplot?چون فقط با داشتن میانگین به نتیجه نمیرسیم و نیاز داریم بفهمیم میانه و حداقل و حداکثر چقدر است
# و با توجه به باکس پلات های رسم شده میزان کلسترل تاثیر چندانی در بیما شدن یا نشدن ندارد
# دایره های تو خالی که بالای هر باکس پلات هست به معنای داده ی پرت است
# با توجه به نمودارهای رسم شده کلسترل ربط چندانی به بیماری قلبی داشتن یا نداشتن افراد ندارد
