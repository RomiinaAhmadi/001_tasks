# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data/heart.csv')

print(df.groupby('target')['thalach'].mean())
print(df.groupby('target')['thalach'].describe())


plt.figure(figsize=(9,6))
sns.boxplot(x='target', y='thalach', data = df)
plt.title('Maximum Heart Rate in Patients and Healthy Individuals')
plt.xlabel('Disease status (0=Healthy , 1= Patient)')
plt.ylabel('Maximum Heart Rate (bpm)')
plt.show()
# Out:
# target
# 0    139.101449
# 1    158.466667
# Name: thalach, dtype: float64
#         count        mean        std   min    25%    50%    75%    max
# target
# 0       138.0  139.101449  22.598782  71.0  125.0  142.0  156.0  195.0
# 1       165.0  158.466667  19.174276  96.0  149.0  161.0  172.0  202.0

# %% [markdown]
# ### سوال 24
# '''
# برای ویژگی thalach بررسی کنید:
#
# حداکثر ضربان قلب در افراد بیمار و سالم چه تفاوتی دارد؟
# '''

# %% [markdown]
# # تحلیل
#
# '''
# print(df.groupby('target')['thalach'].mean())
# داده هارو براساس ستون  target
# گروه بندی میکنه
# برای هر گروه میانگین ستون thalach
# حداکثر ضربان قلب رو محاسبه میکنه
#
# print(df.groupby('target')['thalach'].describe())
# آمار کامل تری از هر گروه میده: تعداد میانگین،انحراف معیار،چارک ها،حداقل و حداکثر
#
# Figure
# بوم نقاشی یا صفحه ی اصلی هست که تموم نموادر روی اون رسم میشن
# figsize=(9,6)
# اندازه بوم مشخص میکنه عرض ۹ اینچ و ارتفاع ۶ اینچ
# یک صفحه ی خالی به ابعاد ۹ در ۶ اینچ برای رسم نموادر ایجاد می کند
#
# Boxplot
# تابع برای رسم نمودار جعبه ای
# X ='target'
# محور افقی ستون target
# سالم = ۰
# بیمار = ۱
# y ='thalach'
# محور عمودی ستون thalach
# حداکثر ضربان قلب
# یک نموادر جعبه ای رسم میکنه که توضیع thalach
# را برای دو گروه سالم و بیمار نشون میده
# Plt.title
# تابع برای تنظیم عنوان نموادر
# 'Maximum Heart Rate in Patients and Healthy Individuals'
# حداکثر ضربان قلب در بیماران و افراد سالم
# Plt.xlabel
# تابع برحسب تنطیم برچسب محور افقی
# وضعیت بیماری
# سالم =۰
# بیمار=۱
# برچسب محور  x رو تنظیم میکنه
# y.label
# تابع برحسب تنطیم برچسب محور افقی
# Maximum Heart Rate (bpm)
# حداکثر ضربان قلب ضربان در دقیقه
# Plt.show
# تابع برای نمایش نموادر در خروجی
#
#
#
# پراکندگی چطوریه؟ سالم ها پراکنده تره،بیماران متمرکز تر
# تمرکز روی چیه؟ بیماران روی ۱۶۰، سالم ها روی ۱۴۰
# چولگی چطوریه؟هردو تقریبا متقارن با چولگی خفیف به چپ
# کشیدگی چطوریه؟بیماران کشیدگی بیشتر ( داده های متمرکز تر)
# ضربان قلب بالا با بیماری رابطه داره
# '''

# %% [markdown]
# # خروجی
# '''
# تعداد بیماران ۱۳۸ نفر
# تعداد افراد سالم ۱۶۵ نفر
# دامنه تغییرات در افراد سالم بیشتره
# نقاط پرت در گروه بیماران یک نقطه پرت زیر ۸۰ وجود  دارد
# حداکثر ضربان قلب یکی از مهم ترین شاخص های تمایز بین افراد سالم و بیمار است هر چه حداکثر ضربان قلب کمتر احتمال بیماری قلبی بیشتر است
# '''
