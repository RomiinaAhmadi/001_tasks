# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("heart.csv")
# print(df['sex'].value_counts())
# print(df.groupby('target')['sex'].value_counts())
(df.groupby('target')['sex']).mean().plot(kind='bar')
plt.xticks([0, 1], ['female', 'male'])
plt.show()

# %% [markdown]
# Analysis of Question 27
#
# مرد=1و زن=0
# میزان مرد و زن ها +میزان مرد ها و زن های بیمار را حساب میکنیم با value_count
# که در همینجا مشخص میکند تعداد زن ها کمتر از مردان است و بیشتر زنان بیمار هستند
# تعداد مردان بیشتر از زنان است وبیشتر از نصف ان ها بیمار نیستند
# برای رسم نمودار نیز از barchartاستفاده میکنیم چون به دلیل نمایش طولی,برای مقایسه راحت تر است
# برای زیبایی و اسانی در فهم از xticksاستفاده میکنیم و جای 0 و 1 از زن و مرد استفاده میکنیم
