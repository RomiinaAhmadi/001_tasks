# %%
import pandas as pd

df =pd.read_csv('data/heart.csv')

corr =df.corr()['target'].sort_values(ascending=False)
print(corr)

# %% [markdown]
# تحلیلcorr
#
#
# همبستگی است یک مفهموم آماری که نوع و شدت رابطه بین دو متغییر رو اندازه میگیره
# مقدارش بین یک و منفی یک است
# Sort
# مرتب سازی یا ترتیب دهی داده ها براساس یک ترتیب خاص
# Sort_values
# مرتب سازی براساس مقادیر یک ستون
# ascending
# مشخص میکنه که داده ها به چه ترتیبی مرتب میشن
#
#
#
# کاربرد:
# شناسایی و الویت بندی ویژگی های بالینی که بیشترین رابطه  مستقیم با بیماری قلبی دارند تا بتونیم در مرحله مدل سازی  روی مهم ترین عوامل تمرکز کنیم
# '''

# %% [markdown]
# خروجی
# Cp
# بیشترین همبستگی مثبت با هدف مربوط به ویژگی است
