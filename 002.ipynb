# %%
import pandas as pd


df = pd.read_csv('data/heart.csv')
df
list(df.columns)
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %% [markdown]
# task002
# kiana

# %% [markdown]
# دیتا ست heart دارای ۱۴ تا ستون است
# که به ترتیب ستون اول (age) نشان دهنده سن کاربران است
#  ستون دوم (sex) هم جنسیت رو نشان می دهد
#  بعدی (cp=chest pain type) که نشان دهنده انواع درد قفسه سینه است ( 1 = آنژین معمولی (Typical angina) | 2 = آنژین غیرمعمول (Atypical angina) |3 = درد غیر مرتبط با قلب (Non-anginal pain) | 4 = بدون علامت (Asymptomatic))
#  (trestbps) است که فشار خودت در حالت استراحت را نشان می دهد
#   (chol) کلسترول خون را نشان می دهد
#   (fbs= Fasting Blood Sugar)
# قند خون ناشتا رو نشان می‌دهد (1 = بیشتر از 120 mg/dl (بالا) | 0 = کمتر یا مساوی 120) ،
#  restecg هم نتیجه نوار قلب در حالت استراحت است (0 = طبیعی | 1 = وجود اختلال | 2 = نشانه‌های هیپرتروفی بطن چپ) ،
#   thalach برای بیشترین ضربان قلب ثبت شده است ،
#    exang هم برای آنژین ناشی از بازی است که 1 یعنی بله و 0 یعنی خیر
#    ، oldpeak افت ST نسبت به حالت استراحت در ECG (مربوط به تست ورزش) ,
#     slope شیب پیک ST در ورزش را نشان می دهد (1 = صعودی | 2 = صاف | 3 = نزولی)،
#      ca هم نشان دهنده تعداد رگ‌های اصلی رنگی شده در فلوروسکوپی (0 تا 3) است، thal
#       هم نتیجه ی تست تالاسمی/اسکن قلب( 3 = طبیعی | 6 = نقص ثابت | 7 = نقص قابل برگشت),
#       آخری (target) برچسب نهایی که نشان می دهد آیا کاربر بیماری قلبی دارد =1 یا ندارد =2.
