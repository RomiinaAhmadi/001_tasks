# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("heart.csv")
df.groupby(['target', 'cp']).size()
# Out:
# target  cp
# 0       0     104
#         1       9
#         2      18
#         3       7
# 1       0      39
#         1      41
#         2      69
#         3      16
# dtype: int64

# %% [markdown]
# Analysis of Question 39
#
# از متد groupbyاستفاده میکنیم برای گروه بندی بر اساس دو ستون خواسته شده
# از sizeاستفاده میکنیم تا بشماریم در هر ردیف به ازای هر تارگت چند cpوجود دارد
# با توجه به خروجی کسانی که بیماری ندارند و cp ان ها صفر است بیشتر است
#
# افرادی که بیماری ندارند عمدتا نوع درد قفسه ی سینه ی ان ها 0 است
# و افراد بیمار نوع درد قفسه سینه ی ان هاعمدتا 2 است و بعد از ان یک(تعداد کمی از افراد مریض درد قفسه سینه ی 3 دارند)
