# %%
import pandas as pd

df = pd.read_csv('data/heart.csv')

sex_counts = df['sex'].value_counts().reset_index()
sex_counts.cloumns = ['Gender', 'count']
sex_counts['Percentage'] = df['sex'].value_counts(normalize =True).values * 100

sex_counts
# Out:
# /tmp/ipykernel_53620/1766728312.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   sex_counts.cloumns = ['Gender', 'count']
#    sex  count  Percentage
# 0    1    207   68.316832
# 1    0     96   31.683168

# %%
### سوال 20
'''
بررسی کنید آیا توزیع جنسیت
(sex) متعادل است یا خیر؟
'''

# %%
# تحلیل
'''
sex_counts = df['sex'].value_counts().reset_index()
این خط دو کار را انجام می‌دهد
df['sex'].value_counts()
تعداد هر مقدار و چند تا ۰ و ۱ رو حساب میکنه
reset_index()
نتیجه رو به دیتافریم تبدیل میکنه که دوتا ستون داره
ستون اول مقادیر sex (0 و 1)
ستون دوم هر کدوم


sex_counts.cloumns = ['Gender', 'count']
اسم ستون هارو تغییر میده

sex_counts['Percentage'] = df['sex'].value_counts(normalize =True).values * 100
ستون جدید اضافه میکنه که درصد هر جنسیت رو نشون بده
نسبت ۰ تا ۱ هر مقدار رو حساب میکنه
.values
فقط مقادیر رو برمیداره
* 100
درصد میکنه
sex_count
دیتا فریم نهایی رو نشون میده
'''

# %%
# خروجی
'''
یه جدول خلاصه از توضیع جنسیت داده ها بهمون میده
بیشتر داده ها متعلق به مردان است
توضیع متعادل نیست
کاربرد:
میگه که موقع  ساخت مدل باید عدم تعادل جنسیتی رو در نظر بگیری
'''
