# %%
import pandas as pd

df = pd.read_csv('data/heart.csv')

grouped = df.groupby(['target', 'sex']).mean()

print(grouped)
# Out:
#                   age        cp    trestbps        chol       fbs   restecg  \
# target sex
# 0      0    59.041667  0.166667  146.125000  274.958333  0.250000  0.541667
#        1    56.087719  0.543860  131.929825  246.061404  0.140351  0.429825
# 1      0    54.555556  1.333333  128.736111  256.750000  0.083333  0.583333
#        1    50.903226  1.408602  129.741935  230.989247  0.182796  0.602151
#
#                thalach     exang   oldpeak     slope        ca      thal
# target sex
# 0      0    142.416667  0.583333  1.841667  0.958333  1.291667  2.500000
#        1    138.403509  0.543860  1.531579  1.210526  1.140351  2.552632
# 1      0    154.027778  0.111111  0.554167  1.583333  0.305556  2.000000
#        1    161.903226  0.161290  0.605376  1.602151  0.408602  2.215054

# %% [markdown]
# task038kiana

# %% [markdown]
# در این قسمت
# 0 افراد بیمار
# 1 افراد سالم
#
# در قسمت اول خانم ها و مرد ها که سن بالاتری داشتند بیمار هستند
#
# هم خانم ها و هم آقایونی که cp بالا تری داشتند سالم هستند
#
# خانم ها و اقایونی که فشار خون و کلسترول بالاتری داشتند بیمار هستند
#
#  خانم هایی که قند خون ناشتا بالا دارن بیمار هستند ولی برای اقایون برعکس هست یعنی اقایونی که قند خون ناشتا پایین تری دارن بیمار هستند
#
# هم خانم ها و هم اقایون با نوار قلب پایین تر بیمار بودند
# و برای thalach که نشان دهنده ضربان قلبه هم کسایی که ضربان قلب پایین دارن بیمار هستند
#
# افرادی که exang بالاتری داشتن یعنی هنگام فعالیت در قفسه سینه شون درد احساس می کردن معمولا بیمار هستند
#
# کسایی که oldpeakو ca وthalبالاتری دارن هم خانم و هم آقا بیمار هستند
#
# در slope هر چه شیب بیشتر بوده یعنی عدد بالا تر بوده افراد سالم تر هستند
