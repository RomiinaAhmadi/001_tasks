# %%
import pandas as pd

df =pd.read_csv('data/heart.csv')
risk_features = ['age','trestbps','chol','thalach','oldpeak']
print(df[risk_features]).describe()
# Out:
#      age  trestbps  chol  thalach  oldpeak
# 0     63       145   233      150      2.3
# 1     37       130   250      187      3.5
# 2     41       130   204      172      1.4
# 3     56       120   236      178      0.8
# 4     57       120   354      163      0.6
# ..   ...       ...   ...      ...      ...
# 298   57       140   241      123      0.2
# 299   45       110   264      132      1.2
# 300   68       144   193      141      3.4
# 301   57       130   131      115      1.2
# 302   57       130   236      174      0.0
#
# [303 rows x 5 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       1 import pandas as pd
#       2
#       3 df =pd.read_csv('data/heart.csv')
#       4 risk_features = ['age','trestbps','chol','thalach','oldpeak']
# ----> 5 print(df[risk_features]).describe()
#
# AttributeError: 'NoneType' object has no attribute 'describe'

# %% [markdown]
# ### سوال 40
# '''
# سه پروفایل مختلف از بیماران استخراج کنید:
#
# مثال:
#
# - بیمار پرریسک
# - بیمار کم‌ریسک
# - بیمار مرزی
#
# (فقط بر اساس مشاهده داده‌ها)
# '''
