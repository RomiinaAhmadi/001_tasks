# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("heart.csv")

df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Analysis of Question 7
#
# از isna()استفاده میکنیم که هرکجا که داده گمشده داشتیم Trueبرگرداند و از sum()استفاده میکنیم که صرفا تعداد داده های گمشده هر ستون را به ما بدهد
# و در اینجا هیچ مقدار گمشده ای نداریم
# داده ی گمشده یعنی بعضی ویژگی ها ثبت نشده باشند و
#  معمولا راه حل این موضوع این است که اگر میشود ان رکورد را حذف کنیم یا از مدل های پیش بینی استفاده کنیم
#   یا میانگین بگیریم از داده های نزدیک یا مقداری ثابت بگذاریم که روش اخر معمولا پبشنهاد نمیشود
