# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("heart.csv")
plt.figure(figsize=(15, 7))
plt.subplot(1, 3, 1)
sns.scatterplot(data=df, x='age', y='chol', hue='target')
plt.subplot(1, 3, 2)
sns.scatterplot(data=df, x='age', y='thalach', hue='target')
plt.subplot(1, 3, 3)
sns.scatterplot(data=df, x='chol', y='trestbps', hue='target')

plt.show()

# %% [markdown]
# Analysis of Question 35
#
# از scatter plotاستفاده میکنیم برای پیدا کردن روابط
# چون قصد داریم در یک تصویر تمامی نمودارهارا رسم کنیم و نمایش دهیم پس
# از subplotاستفاده میکنیم
# درنمودار اول از سمت چپ:تجمیع در سن 50 تا 60 برای کلسترل بیشتر است
# نمودار دوم:افراد بیماری که در بازه ی 50 تا 60 سال قرار دارند در حداکثر میزان ضربان قلب 140 تا 180 است
# و در نمودار سوم:افراد در بازه ی 200 تا 300 کلسترل بیشتری دارند که همراه با فشار خون در حال استراحتی که در بازه 120 تا 160 قرار دارد
